# %% [markdown]
# #  **Assignment**

# %% [markdown]
# Question 1 : What is Simple Linear Regression (SLR)? Explain its purpose.
# >>Simple Linear Regression (SLR) is a statistical and machine-learning technique used to model the relationship between two variables:
#
# One independent variable (X)
#
# One dependent variable (Y)
#
# It assumes that the relationship between X and Y can be represented by a straight line.
#
# Mathematical Form
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c
#
# Where:
#
# 𝑌
# Y = dependent variable (output)
#
# 𝑋
# X = independent variable (input)
#
# 𝑚
# m = slope (change in Y for one unit change in X)
#
# 𝑐
# c = intercept (value of Y when X = 0)
#
# Purpose of Simple Linear Regression
#
# To understand relationships
# It helps identify how one variable affects another
# (e.g., how study hours affect exam marks).
#
# To make predictions
# Once the model is trained, it can predict Y for a new value of X
# (e.g., predicting salary based on years of experience).
#
# To quantify impact
# The slope
# 𝑚
# m tells how much Y increases or decreases when X changes.
#
# To analyze trends
# Useful in economics, data science, environmental studies, and business analysis.
#
# Example
#
# X: Hours studied
#
# Y: Exam score
#
# SLR helps answer: “If a student studies 1 extra hour, how much will the score increase?”

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?
# >>Key Assumptions of Simple Linear Regression (SLR)
#
# Simple Linear Regression works correctly only when the following assumptions are satisfied:
#
# Linearity
# The relationship between the independent variable (X) and dependent variable (Y) must be linear.
#
# Independence
# The observations (data points) should be independent of each other.
#
# Homoscedasticity
# The variance of errors should be constant across all values of X
# (i.e., equal spread of residuals).
#
# Normality of Errors
# The residuals (errors) should be normally distributed.
#
# No or Minimal Outliers
# Extreme outliers should not strongly influence the regression line.

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and
# explain each term.
# >>Mathematical Equation of Simple Linear Regression
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c
# Explanation of Each Term
#
# 𝑌
# Y → Dependent variable (output/response)
# This is the value we want to predict.
#
# 𝑋
# X → Independent variable (input/predictor)
# This is the variable used to explain or predict Y.
#
# 𝑚
# m → Slope of the regression line
# It shows the change in Y for a one-unit change in X.
#
# 𝑐
# c → Intercept
# It represents the value of Y when X = 0.
#
# Alternative notation (often used in ML/statistics)
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
#
# Where:
#
# 𝛽
# 0
# β
# 0
# 	​
#
#  = intercept
#
# 𝛽
# 1
# β
# 1
# 	​
#
#  = slope
#
# 𝜀
# ε = error term (difference between actual and predicted value)

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be
# applied.
# >>Real-World Example of Simple Linear Regression
#
# Example: Predicting Salary Based on Years of Experience
#
# Independent variable (X): Years of experience
#
# Dependent variable (Y): Salary
#
# Simple Linear Regression can be used to analyze how salary changes with experience and to predict the salary of a person based on their years of work experience.
#
# Explanation
#
# If data shows that salary increases in a roughly straight-line pattern as experience increases, SLR can model this relationship and answer questions like:
#
# How much does salary increase per additional year of experience?
#
# What salary can be expected for 5 years of experience?
#
# Other real-world examples
#
# Predicting house price based on house size
#
# Estimating electricity bill based on units consumed
#
# Predicting exam marks based on hours studied

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?
# >>
# Method of Least Squares in Linear Regression
#
# The method of least squares is a technique used to find the best-fitting straight line in linear regression by minimizing the sum of squared errors between the actual values and the predicted values.
#
# Explanation
#
# In Simple Linear Regression, each data point has:
#
# Actual value:
# 𝑌
# 𝑖
# Y
# i
# 	​
#
#
# Predicted value:
# 𝑌
# ^
# 𝑖
# Y
# ^
# i
# 	​
#
#
# The error (residual) is:
#
# 𝑒
# 𝑖
# =
# 𝑌
# 𝑖
# −
# 𝑌
# ^
# 𝑖
# e
# i
# 	​
#
# =Y
# i
# 	​
#
# −
# Y
# ^
# i
# 	​
#
#
# The least squares method chooses the line such that:
#
# ∑
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ^
# 𝑖
# )
# 2
# ∑(Y
# i
# 	​
#
# −
# Y
# ^
# i
# 	​
#
# )
# 2
#
# is minimum.
#
# Why squared errors?
#
# Squaring removes negative signs
#
# Larger errors are penalized more
#
# Makes the math easier to optimize
#
# Purpose
#
# To estimate the best values of slope (m) and intercept (c)
#
# To ensure the regression line fits the data as closely as possible

# %% [markdown]
# Question 6: What is Logistic Regression? How does it differ from Linear Regression?
# >>Logistic Regression is a supervised machine learning algorithm used for classification problems, mainly when the output is binary (0/1, Yes/No, True/False).
#
# Instead of predicting a continuous value, it predicts the probability that an input belongs to a particular class using the sigmoid function.
#
# Mathematical form:
#
# 𝑃
# (
# 𝑌
# =
# 1
# )
# =
# 1
# 1
# +
# 𝑒
# −
# (
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# )
# P(Y=1)=
# 1+e
# −(β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X)
# 1
# Difference Between Linear Regression and Logistic Regression.
# >>​
# | Aspect           | Linear Regression        | Logistic Regression      |
# | ---------------- | ------------------------ | ------------------------ |
# | Type of problem  | Regression               | Classification           |
# | Output           | Continuous values        | Probability (0–1)        |
# | Target variable  | Numerical                | Categorical (Binary)     |
# | Model function   | Straight line            | Sigmoid (S-shaped curve) |
# | Prediction range | (-\infty) to (+\infty)   | 0 to 1                   |
# | Loss function    | Mean Squared Error (MSE) | Log Loss (Cross-Entropy) |
# | Example          | Predicting house price   | Spam vs Not Spam         |

# %% [markdown]
# Question 7: Name and briefly describe three common evaluation metrics for regression
# models.
# >>
# Three Common Evaluation Metrics for Regression Models
#
# Mean Absolute Error (MAE)
# MAE measures the average absolute difference between actual and predicted values.
# It is easy to understand and treats all errors equally.
#
# 𝑀
# 𝐴
# 𝐸
# =
# 1
# 𝑛
# ∑
# ∣
# 𝑌
# 𝑖
# −
# 𝑌
# ^
# 𝑖
# ∣
# MAE=
# n
# 1
# 	​
#
# ∑∣Y
# i
# 	​
#
# −
# Y
# ^
# i
# 	​
#
# ∣
#
# Mean Squared Error (MSE)
# MSE measures the average of squared differences between actual and predicted values.
# It penalizes large errors more heavily due to squaring.
#
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 𝑛
# ∑
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ^
# 𝑖
# )
# 2
# MSE=
# n
# 1
# 	​
#
# ∑(Y
# i
# 	​
#
# −
# Y
# ^
# i
# 	​
#
# )
# 2
#
# Root Mean Squared Error (RMSE)
# RMSE is the square root of MSE, making it easier to interpret because it has the same unit as the target variable.
#
# 𝑅
# 𝑀
# 𝑆
# 𝐸
# =
# 𝑀
# 𝑆
# 𝐸
# RMSE=
# MSE
# 	​

# %% [markdown]
# Question 8: What is the purpose of the R-squared metric in regression analysis?
# >>
# Purpose of R-squared (R²) in Regression Analysis
#
# R-squared (R²) is a statistical metric used to measure how well a regression model explains the variability of the dependent variable.
#
# In simple words, it tells us how much of the change in the output variable is explained by the input variable(s).
#
# Key Points
#
# R² value ranges from 0 to 1
#
# R² = 0 → Model explains none of the variability
#
# R² = 1 → Model explains all the variability
#
# Higher R² → Better model fit (generally)
#
# Example
#
# If R² = 0.80, it means:
#
# 80% of the variation in Y is explained by X, and 20% is due to other factors or noise.
#
# Purpose Summarized
#
# Evaluates goodness of fit of the model
#
# Helps compare regression models
#
# Indicates explanatory power of predictors

# %% [markdown]
# Question 9: Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
# (Include your Python code and output in the code box below.)
# >>

# %%
# Simple Linear Regression using scikit-learn

import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)   # Independent variable
y = np.array([2, 4, 6, 8, 10])                 # Dependent variable

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Print slope and intercept
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 2.0
# Intercept (c): 0.0

# %% [markdown]
# Question 10: How do you interpret the coefficients in a simple linear regression model?
# >>
# Interpretation of Coefficients in Simple Linear Regression
#
# In a simple linear regression model:
#
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c
#
# the coefficients are interpreted as follows:
#
# 1. Slope (m)
#
# The slope represents the change in the dependent variable (Y) for a one-unit increase in the independent variable (X).
#
# If m > 0, Y increases as X increases (positive relationship).
#
# If m < 0, Y decreases as X increases (negative relationship).
#
# Example:
# If
# 𝑚
# =
# 2
# m=2, it means Y increases by 2 units when X increases by 1 unit.
#
# 2. Intercept (c)
#
# The intercept is the value of Y when X = 0.
#
# It provides the baseline value of the dependent variable.
#
# Example:
# If
# 𝑐
# =
# 5
# c=5, it means Y = 5 when X = 0
